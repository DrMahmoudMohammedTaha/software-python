# %%
# !pip install Office365-REST-Python-Client
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting Office365-REST-Python-Client
#   Downloading Office365_REST_Python_Client-2.3.13-py3-none-any.whl (546 kB)
#      |████████████████████████████████| 546 kB 25.3 MB/s
# Collecting msal
#   Downloading msal-1.18.0-py2.py3-none-any.whl (82 kB)
#      |████████████████████████████████| 82 kB 755 kB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from Office365-REST-Python-Client) (2.23.0)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from Office365-REST-Python-Client) (2022.1)
# Requirement already satisfied: cryptography<40,>=0.6 in /usr/local/lib/python3.7/dist-packages (from msal->Office365-REST-Python-Client) (37.0.2)
# Collecting PyJWT[crypto]<3,>=1.0.0
#   Downloading PyJWT-2.4.0-py3-none-any.whl (18 kB)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.7/dist-packages (from cryptography<40,>=0.6->msal->Office365-REST-Python-Client) (1.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.12->cryptography<40,>=0.6->msal->Office365-REST-Python-Client) (2.21)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->Office365-REST-Python-Client) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->Office365-REST-Python-Client) (2022.6.15)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->Office365-REST-Python-Client) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->Office365-REST-Python-Client) (3.0.4)
# Installing collected packages: PyJWT, msal, Office365-REST-Python-Client
# Successfully installed Office365-REST-Python-Client-2.3.13 PyJWT-2.4.0 msal-1.18.0

# %%
from office365.runtime.auth.user_credential import UserCredential
from office365.sharepoint.client_context import ClientContext
site_url = "https://fengbuedu.sharepoint.com/sites/Otor"
sp_list = "ORDER"
ctx = ClientContext(site_url).with_credentials(UserCredential("mahmoud.taha17@feng.bu.edu.eg", "Omabdo2020"))
sp_lists = ctx.web.lists
s_list = sp_lists.get_by_title(sp_list)
l_items = s_list.get_items()
ctx.load(l_items)
ctx.execute_query()

for item in l_items:
    print(item.properties['SHEIKH_NAME'],item.properties['COST'])
# Out:
# محمد محمود عبد الجواد 230
# شيرين عمرو محمد عبد المولى 360
# مرفت السيد صادق الاديب 340
# فاطمة فرج عبد الله 0
# صفاء محمد محمد البسيوني 300
# علاء محمد 180
# طلب سريع 180
# محمد حسين صديق عيد 120
# عصام بيومى 200
# طلب سريع 0

# %%
from office365.runtime.auth.user_credential import UserCredential
from office365.sharepoint.client_context import ClientContext
site_url = "https://fengbuedu.sharepoint.com/sites/Otor"
sp_list = "ORDER"
ctx = ClientContext(site_url).with_credentials(UserCredential("mahmoud.taha17@feng.bu.edu.eg", "Omabdo2020"))
sp_lists = ctx.web.lists
s_list = sp_lists.get_by_title(sp_list)
l_items = s_list.get_items()

item = s_list.get_item_by_id(496)
item.set_property('SHEIKH_NAME', 'HAMADA')
item.set_property('COST', '999')
item.update()
ctx.execute_query()
